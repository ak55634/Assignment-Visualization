# %% [markdown]
# <a href="https://colab.research.google.com/github/ak55634/Assignment-Visualization/blob/main/D_CPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd

# uploaded file 'D_CPT.csv'
d_cpt = pd.read_csv('D_CPT.csv')

# Display the first few rows
print(services.head())

# %%
import pandas as pd
import matplotlib.pyplot as plt # Import the matplotlib library and alias it as plt

# Pie Chart of Top 10 CPT Codes
top_10_cpt = d_cpt['SECTIONHEADER'].value_counts().head(10)
plt.pie(top_10_cpt, labels=top_10_cpt.index, autopct='%1.1f%%')
plt.title('Top 10 Sections')
plt.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.
plt.show()
